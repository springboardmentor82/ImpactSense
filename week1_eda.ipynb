# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import folium

# %% [markdown]
# # 🌍 ImpactSense - Earthquake Impact Prediction
# ## Week 1: Exploratory Data Analysis (EDA)

# %% [markdown]
# Load dataset  <----

# %%
data = pd.read_csv("Earthquakes_Dataset.csv")
data.head()
# Out:
#                              place   mag magType        type  \
# 0         113 km W of Petrolia, CA  2.56      md  earthquake
# 1               9 km N of Taft, CA  1.54      ml  earthquake
# 2        58 km WNW of Petrolia, CA  2.84      md  earthquake
# 3  24 km NNW of Searles Valley, CA  1.49      ml  earthquake
# 4            12 km WNW of Anza, CA  0.56      ml  earthquake
#
#                       time   longitude   latitude  depth_km  sig net   nst  \
# 0  2025-02-11 14:34:38.190 -125.614334  40.216499      4.95  101  nc  14.0
# 1  2025-02-11 14:28:19.490 -119.456833  35.225167     18.24   36  ci  31.0
# 2  2025-02-11 14:24:27.270 -124.964500  40.401165      4.20  124  nc  30.0
# 3  2025-02-11 14:24:22.730 -117.515663  35.967335      4.01   34  ci  19.0
# 4  2025-02-11 14:12:30.720 -116.803167  33.584500      8.69    5  ci  25.0
#
#       dmin   rms    gap
# 0  0.97600  0.12  325.0
# 1  0.08479  0.20  116.0
# 2  0.48850  0.37  274.0
# 3  0.11100  0.16   83.0
# 4  0.05820  0.16   69.0

# %% [markdown]
# ----->  Dataset information

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22738 entries, 0 to 22737
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   place      22738 non-null  object
#  1   mag        22738 non-null  float64
#  2   magType    22738 non-null  object
#  3   type       22738 non-null  object
#  4   time       22738 non-null  object
#  5   longitude  22738 non-null  float64
#  6   latitude   22738 non-null  float64
#  7   depth_km   22738 non-null  float64
#  8   sig        22738 non-null  int64
#  9   net        22738 non-null  object
#  10  nst        22738 non-null  float64
#  11  dmin       22738 non-null  float64
#  12  rms        22738 non-null  float64
#  13  gap        22738 non-null  float64
# dtypes: float64(8), int64(1), object(5)
# memory usage: 2.4+ MB

# %% [markdown]
# -----> Summary statistics

# %%
data.describe()
# Out:
#                 mag     longitude      latitude      depth_km           sig  \
# count  22738.000000  22738.000000  22738.000000  22738.000000  22738.000000
# mean       1.481742   -100.489911     36.216841     15.467917     67.213827
# std        1.468251     69.446986     17.141390     53.243223    109.585431
# min       -1.890000   -179.964000    -73.220400     -3.460000      0.000000
# 25%        0.600000   -122.821831     33.506333      2.270000      6.000000
# 50%        1.110000   -119.039833     38.492850      6.245400     19.000000
# 75%        1.910000   -110.815375     40.354167     10.000000     56.750000
# max        7.600000    179.971600     82.479300    690.121000   1177.000000
#
#                 nst          dmin           rms           gap
# count  22738.000000  22738.000000  22738.000000  22738.000000
# mean      24.452458      0.487572      0.216859    111.526936
# std       22.927217      1.823934      0.264214     63.769321
# min        3.000000      0.000000      0.000000     14.000000
# 25%        9.000000      0.013820      0.060000     65.000000
# 50%       17.000000      0.052585      0.130000     91.000000
# 75%       31.000000      0.125000      0.210000    146.000000
# max      242.000000     29.638000      1.720000    348.000000

# %% [markdown]
# -------->  Data type check

# %%
print("Data Types:")
data.dtypes
# Out:
# Data Types:
# place         object
# mag          float64
# magType       object
# type          object
# time          object
# longitude    float64
# latitude     float64
# depth_km     float64
# sig            int64
# net           object
# nst          float64
# dmin         float64
# rms          float64
# gap          float64
# dtype: object

# %% [markdown]
# ------>  Data type correction

# %%
data['time'] = pd.to_datetime(data['time'], errors='coerce')

print("Updated Data Types:")
data.dtypes
# Out:
# Updated Data Types:
# place                object
# mag                 float64
# magType              object
# type                 object
# time         datetime64[ns]
# longitude           float64
# latitude            float64
# depth_km            float64
# sig                   int64
# net                  object
# nst                 float64
# dmin                float64
# rms                 float64
# gap                 float64
# dtype: object

# %% [markdown]
# -------->  Missing values

# %%
print("Missing Values in Each Column:")
data.isnull().sum()
# Out:
# Missing Values in Each Column:
# place          0
# mag            0
# magType        0
# type           0
# time         138
# longitude      0
# latitude       0
# depth_km       0
# sig            0
# net            0
# nst            0
# dmin           0
# rms            0
# gap            0
# dtype: int64

# %% [markdown]
# ----->  Duplicate removal

# %%
print("Shape before removing duplicates:", data.shape)

data = data.drop_duplicates()

print("Shape after removing duplicates:", data.shape)
# Out:
# Shape before removing duplicates: (22738, 14)
# Shape after removing duplicates: (8810, 14)

# %% [markdown]
# ---->  Magnitude distribution

# %%
plt.figure(figsize=(8,4))
sns.histplot(data['mag'], kde=True)
plt.title("Magnitude Distribution")
plt.show()

# %% [markdown]
# ----->  Depth distribution

# %%
plt.figure(figsize=(8,4))
sns.histplot(data['depth_km'], kde=True)
plt.title("Depth Distribution")
plt.show()

# %% [markdown]
# -------->  Outlier detection

# %%
plt.figure(figsize=(8,4))
sns.boxplot(x=data['mag'])
plt.title("Outlier Detection - Magnitude")
plt.show()

# %% [markdown]
# ---------->   Earthquake map

# %%
map_eq = folium.Map(
    location=[data['latitude'].mean(), data['longitude'].mean()],
    zoom_start=2
)

for i in range(min(300, len(data))):
    folium.CircleMarker(
        location=[data.iloc[i]['latitude'], data.iloc[i]['longitude']],
        radius=3,
        color='red',
        fill=True
    ).add_to(map_eq)

map_eq
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dd7a6e4f7021c2137628036fc2c1bc4f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dd7a6e4f7021c2137628036fc2c1bc4f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dd7a6e4f7021c2137628036fc2c1bc4f = L.map(
#                 &quot;map_dd7a6e4f7021c2137628036fc2c1bc4f&quot;,
#                 {
#                     center: [35.8652309700035, -98.43010566531906],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f9577fe0062fd9bf4f4f6b2c57f018da = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f9577fe0062fd9bf4f4f6b2c57f018da.addTo(map_dd7a6e4f7021c2137628036fc2c1bc4f);
#
#
#             var circle_marker_cf72fbbe4255cc2038d0dfbb0c6d7e94 = L.circleMarker(
#                 [40.2164993286133, -125.614334106445],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_dd7a6e4f7021c2137628036fc2c1bc4f);
#
#
#             var circle_marker_f0ee9f89516b9ad4c9fb6333a60f3e1d = L.circleMarker(
#                 [35.2251667, -119.4568333],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_dd7a6e4f7021c2137628036fc2c1bc4f);
#
#
#             var circle_marker_3a33afd218fcd3244bbc4e85d9e78679 = L.circleMarker(
#                 [40.4011650085449, -124.964500427246],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_dd7a6e4f7021c2137628036fc2c1bc4f);
#
#
#             var circle_marker_5cbc2d71999e1b6e932e2ae10f582afb = L.circleMarker(
#                 [35.9673347, -117.5156631],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_dd7a6e4f7021c2137628036fc2c1bc4f);
#
#
#             var circle_marker_7cdcb71015030b7be0aedb87c1ca29c1 = L.circleMarker(
#                 [33.5845, -116.8031667],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_dd7a6e4f7021c2137628036fc2c1bc4f);
#
#
#             var circle_marker_e9ddb1a66a25c8a69bcfcd85fd62263c = L.circleMarker(
#                 [35.15183333, -97.57633333],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_dd7a6e4f7021c2137628036fc2c1bc4f);
#
#
#             var circle_marker_52b9d80d53a84d94b4c1a9aa1950f29f = L.circleMarker(
#                 [38.8139991760254, -122
